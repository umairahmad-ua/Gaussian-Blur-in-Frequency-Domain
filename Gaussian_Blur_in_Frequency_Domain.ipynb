# %%
import matplotlib.pyplot as plt
from matplotlib import cm
from skimage.color import rgb2gray
from skimage.io import imread
import scipy.fftpack as fp
from scipy import signal
import numpy as np

# %% [markdown]
# # Result of Guassian filter after one pass

# %%
im = rgb2gray(imread('/content/Cameraman.bmp'))
for x in range(1):
  kernel = np.outer(signal.gaussian(im.shape[0], 2), signal.gaussian(im.shape[1], 2))
  freq = fp.fft2(im)
  freq_kernel = fp.fft2(fp.ifftshift(kernel))
  convolved = freq*freq_kernel # by the Convolution theorem
  im_blur = fp.ifft2(convolved).real
  im = 255 * im_blur / np.max(im_blur)
 

 
plt.figure(figsize=(10,10))
plt.imshow(im, cmap='gray')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.

# %% [markdown]
# # Result of Guassian filter after 10 passes

# %%
im = rgb2gray(imread('/content/Cameraman.bmp'))
for x in range(10):
  kernel = np.outer(signal.gaussian(im.shape[0], 2), signal.gaussian(im.shape[1], 2))
  freq = fp.fft2(im)
  freq_kernel = fp.fft2(fp.ifftshift(kernel))
  convolved = freq*freq_kernel # by the Convolution theorem
  im_blur = fp.ifft2(convolved).real
  im = 255 * im_blur / np.max(im_blur)
 

 
plt.figure(figsize=(10,10))
plt.imshow(im, cmap='gray')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.

# %% [markdown]
# # Result of Guassian filter after 100 passes

# %%
im = rgb2gray(imread('/content/Cameraman.bmp'))
for x in range(100):
  kernel = np.outer(signal.gaussian(im.shape[0], 2), signal.gaussian(im.shape[1], 2))
  freq = fp.fft2(im)
  freq_kernel = fp.fft2(fp.ifftshift(kernel))
  convolved = freq*freq_kernel # by the Convolution theorem
  im_blur = fp.ifft2(convolved).real
  im = 255 * im_blur / np.max(im_blur)
 

 
plt.figure(figsize=(10,10))
plt.imshow(im, cmap='gray')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# # Result of Guassian filter after 10000 passes

# %%
im = rgb2gray(imread('/content/Cameraman.bmp'))
for x in range(10000):
  kernel = np.outer(signal.gaussian(im.shape[0], 10), signal.gaussian(im.shape[1],10))
  freq = fp.fft2(im)
  freq_kernel = fp.fft2(fp.ifftshift(kernel))
  convolved = freq*freq_kernel # by the Convolution theorem
  im_blur = fp.ifft2(convolved).real
  im = 255 * im_blur / np.max(im_blur)
 

 
plt.figure(figsize=(10,10))
plt.imshow(im, cmap='gray')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# # Image will get wipe out after apply gussian filter again and again
